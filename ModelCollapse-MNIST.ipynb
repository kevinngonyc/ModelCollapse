# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torchvision.utils import make_grid
from torch.utils.data import TensorDataset
import numpy as np

# %%
latent_dims = 20
num_epochs = 30
batch_size = 256
capacity = 64
learning_rate = 1e-3
variational_beta = 1

# %%
train_dataset = datasets.MNIST(root='./data', train = True, download = True, transform = ToTensor())
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataset = datasets.MNIST(root='./data', train = False, download = True, transform = ToTensor())
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)

# %%
class Encoder(nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()
        c = capacity
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=c, kernel_size=4, stride=2, padding=1) # out: c x 14 x 14
        self.conv2 = nn.Conv2d(in_channels=c, out_channels=c*2, kernel_size=4, stride=2, padding=1) # out: c x 7 x 7
        self.fc_mu = nn.Linear(in_features=c*2*7*7, out_features=latent_dims)
        self.fc_logvar = nn.Linear(in_features=c*2*7*7, out_features=latent_dims)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = x.view(x.size(0), -1) # flatten batch of multi-channel feature maps to a batch of feature vectors
        x_mu = self.fc_mu(x)
        x_logvar = self.fc_logvar(x)
        return x_mu, x_logvar

class Decoder(nn.Module):
    def __init__(self):
        super(Decoder, self).__init__()
        c = capacity
        self.fc = nn.Linear(in_features=latent_dims, out_features=c*2*7*7)
        self.conv2 = nn.ConvTranspose2d(in_channels=c*2, out_channels=c, kernel_size=4, stride=2, padding=1)
        self.conv1 = nn.ConvTranspose2d(in_channels=c, out_channels=1, kernel_size=4, stride=2, padding=1)

    def forward(self, x):
        x = self.fc(x)
        x = x.view(x.size(0), capacity*2, 7, 7) # unflatten batch of feature vectors to a batch of multi-channel feature maps
        x = F.relu(self.conv2(x))
        x = torch.sigmoid(self.conv1(x)) # last layer before output is sigmoid, since we are using BCE as reconstruction loss
        return x

class VariationalAutoencoder(nn.Module):
    def __init__(self):
        super(VariationalAutoencoder, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()

    def forward(self, x):
        latent_mu, latent_logvar = self.encoder(x)
        latent = self.latent_sample(latent_mu, latent_logvar)
        x_recon = self.decoder(latent)
        return x_recon, latent_mu, latent_logvar

    def latent_sample(self, mu, logvar, sampleme=False):
        if self.training or sampleme:
            # the reparameterization trick
            std = logvar.mul(0.5).exp_()
            eps = torch.empty_like(std).normal_()
            return eps.mul(std).add_(mu)
        else:
            return mu

def vae_loss(recon_x, x, mu, logvar):
    # recon_x is the probability of a multivariate Bernoulli distribution p.
    # -log(p(x)) is then the pixel-wise binary cross-entropy.
    # Averaging or not averaging the binary cross-entropy over all pixels here
    # is a subtle detail with big effect on training, since it changes the weight
    # we need to pick for the other loss term by several orders of magnitude.
    # Not averaging is the direct implementation of the negative log likelihood,
    # but averaging makes the weight of the other loss term independent of the image resolution.
    recon_loss = F.binary_cross_entropy(recon_x.view(-1, 784), x.view(-1, 784), reduction='sum')

    # KL-divergence between the prior distribution over latent vectors
    # (the one we are going to sample from when generating new images)
    # and the distribution estimated by the generator for the given image.
    kldivergence = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

    return recon_loss + variational_beta * kldivergence


vae_init = VariationalAutoencoder().to(device)

num_params = sum(p.numel() for p in vae_init.parameters() if p.requires_grad)
print('Number of parameters: %d' % num_params)
# Out:
# Number of parameters: 647081

# %%
def train_vae_gen(vae, sample_vae=False, sample_from=None):
  vae = vae.to(device)

  num_params = sum(p.numel() for p in vae.parameters() if p.requires_grad)
  print('Number of parameters: %d' % num_params)

  optimizer = torch.optim.Adam(params=vae.parameters(), lr=learning_rate, weight_decay=1e-5)

  vae.train()

  train_loss_avg = []

  print('Training ...')
  for epoch in range(num_epochs):
      train_loss_avg.append(0)
      num_batches = 0

      for image_batch, _ in train_dataloader:

          image_batch = image_batch.to(device)

          if sample_vae:
            with torch.no_grad():
              # image_batch = image_batch.to(device)
              latent = torch.randn(image_batch.shape[0], latent_dims, device=device)
              image_batch = sample_from.decoder(latent)

          # vae reconstruction
          image_batch_recon, latent_mu, latent_logvar = vae(image_batch)

          # reconstruction error
          loss = vae_loss(image_batch_recon, image_batch, latent_mu, latent_logvar)

          # backpropagation
          optimizer.zero_grad()
          loss.backward()

          # one step of the optmizer (using the gradients from backpropagation)
          optimizer.step()

          train_loss_avg[-1] += loss.item()
          num_batches += 1

      train_loss_avg[-1] /= num_batches
      print('Epoch [%d / %d] average reconstruction error: %f' % (epoch+1, num_epochs, train_loss_avg[-1]))

# %%
train_vae_gen(vae_init, False, None)
# Out:
# Number of parameters: 647081
# Training ...
# Epoch [1 / 30] average reconstruction error: 41667.628944
# Epoch [2 / 30] average reconstruction error: 29254.356877
# Epoch [3 / 30] average reconstruction error: 27907.926035
# Epoch [4 / 30] average reconstruction error: 27303.260381
# Epoch [5 / 30] average reconstruction error: 26912.114632
# Epoch [6 / 30] average reconstruction error: 26657.152477
# Epoch [7 / 30] average reconstruction error: 26480.100087
# Epoch [8 / 30] average reconstruction error: 26321.327315
# Epoch [9 / 30] average reconstruction error: 26219.574830
# Epoch [10 / 30] average reconstruction error: 26093.257775
# Epoch [11 / 30] average reconstruction error: 25994.487762
# Epoch [12 / 30] average reconstruction error: 25907.531936
# Epoch [13 / 30] average reconstruction error: 25835.846651
# Epoch [14 / 30] average reconstruction error: 25777.911532
# Epoch [15 / 30] average reconstruction error: 25698.059475
# Epoch [16 / 30] average reconstruction error: 25644.948600
# Epoch [17 / 30] average reconstruction error: 25588.326504
# Epoch [18 / 30] average reconstruction error: 25528.854355
# Epoch [19 / 30] average reconstruction error: 25470.137014
# Epoch [20 / 30] average reconstruction error: 25431.460838
# Epoch [21 / 30] average reconstruction error: 25388.694515
# Epoch [22 / 30] average reconstruction error: 25357.413489
# Epoch [23 / 30] average reconstruction error: 25315.074194
# Epoch [24 / 30] average reconstruction error: 25267.769190
# Epoch [25 / 30] average reconstruction error: 25228.646293
# Epoch [26 / 30] average reconstruction error: 25210.282497
# Epoch [27 / 30] average reconstruction error: 25177.797232
# Epoch [28 / 30] average reconstruction error: 25153.549501
# Epoch [29 / 30] average reconstruction error: 25123.943551
# Epoch [30 / 30] average reconstruction error: 25096.679147

# %%
plt.ion()

vae_init.eval()

# This function takes as an input the images to reconstruct
# and the name of the model with which the reconstructions
# are performed
def to_img(x):
    x = x.clamp(0, 1)
    return x

def show_image(img):
    img = to_img(img)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

def visualise_output(images, model):

    with torch.no_grad():

        images = images.to(device)
        images, _, _ = model(images)
        images = images.cpu()
        images = to_img(images)
        np_imagegrid = make_grid(images[1:50], 10, 5).numpy()
        plt.imshow(np.transpose(np_imagegrid, (1, 2, 0)))
        plt.show()

for images, labels in test_dataloader:
  break

# First visualise the original images
print('Original images')
show_image(make_grid(images[1:50],10,5))
plt.show()

# Reconstruct and visualise the images using the vae
print('VAE reconstruction:')
visualise_output(images, vae_init)
# Out:
# Original images
# VAE reconstruction:

# %%
latent = torch.randn(128, latent_dims, device=device)

# reconstruct images from the latent vectors
img_recon = vae_init.decoder(latent)
img_recon = img_recon.cpu()

fig, ax = plt.subplots(figsize=(5, 5))
show_image(make_grid(img_recon.data[:100],10,5))
# plt.show()
plt.xticks([])
plt.yticks([])

plt.tight_layout()

# %%
samples = []
for i in range(20):
    print(f"Generation {i}")
    samples.append(img_recon.data[:100])

    latent = torch.randn(60000, latent_dims, device=device)
    
    # reconstruct images from the latent vectors
    img_recon = vae_init.decoder(latent).clone().detach()
    train_recon = TensorDataset(img_recon, torch.zeros(60000, 1))
    train_dataloader = DataLoader(train_recon, batch_size=batch_size, shuffle=True)
    train_vae_gen(vae_init, False, None)
# Out:
# Generation 0
# Number of parameters: 647081
# Training ...
# Epoch [1 / 30] average reconstruction error: 31210.929164
# Epoch [2 / 30] average reconstruction error: 30961.542171
# Epoch [3 / 30] average reconstruction error: 30917.409038
# Epoch [4 / 30] average reconstruction error: 30889.659263
# Epoch [5 / 30] average reconstruction error: 30866.264266
# Epoch [6 / 30] average reconstruction error: 30844.172120
# Epoch [7 / 30] average reconstruction error: 30843.560189
# Epoch [8 / 30] average reconstruction error: 30837.445770
# Epoch [9 / 30] average reconstruction error: 30824.351359
# Epoch [10 / 30] average reconstruction error: 30816.893796
# Epoch [11 / 30] average reconstruction error: 30804.152884
# Epoch [12 / 30] average reconstruction error: 30796.229546
# Epoch [13 / 30] average reconstruction error: 30795.919706
# Epoch [14 / 30] average reconstruction error: 30792.457530
# Epoch [15 / 30] average reconstruction error: 30783.180918
# Epoch [16 / 30] average reconstruction error: 30782.379409
# Epoch [17 / 30] average reconstruction error: 30770.676641
# Epoch [18 / 30] average reconstruction error: 30775.856965
# Epoch [19 / 30] average reconstruction error: 30773.524751
# Epoch [20 / 30] average reconstruction error: 30755.225952
# Epoch [21 / 30] average reconstruction error: 30756.748288
# Epoch [22 / 30] average reconstruction error: 30756.328919
# Epoch [23 / 30] average reconstruction error: 30758.951205
# Epoch [24 / 30] average reconstruction error: 30756.527173
# Epoch [25 / 30] average reconstruction error: 30743.307260
# Epoch [26 / 30] average reconstruction error: 30749.739495
# Epoch [27 / 30] average reconstruction error: 30741.795645
# Epoch [28 / 30] average reconstruction error: 30742.895678
# Epoch [29 / 30] average reconstruction error: 30745.996809
# Epoch [30 / 30] average reconstruction error: 30739.762384
# Generation 1
# Number of parameters: 647081
# Training ...
# Epoch [1 / 30] average reconstruction error: 33619.553694
# Epoch [2 / 30] average reconstruction error: 33559.691631
# Epoch [3 / 30] average reconstruction error: 33554.105544
# Epoch [4 / 30] average reconstruction error: 33543.609321
# Epoch [5 / 30] average reconstruction error: 33537.056192
# Epoch [6 / 30] average reconstruction error: 33532.755111
# Epoch [7 / 30] average reconstruction error: 33534.720699
# Epoch [8 / 30] average reconstruction error: 33528.967786
# Epoch [9 / 30] average reconstruction error: 33524.488614
# Epoch [10 / 30] average reconstruction error: 33523.548787
# Epoch [11 / 30] average reconstruction error: 33520.459853
# Epoch [12 / 30] average reconstruction error: 33512.386598
# Epoch [13 / 30] average reconstruction error: 33513.573737
# Epoch [14 / 30] average reconstruction error: 33513.658037
# Epoch [15 / 30] average reconstruction error: 33516.076978
# Epoch [16 / 30] average reconstruction error: 33511.824863
# Epoch [17 / 30] average reconstruction error: 33510.248180
# Epoch [18 / 30] average reconstruction error: 33516.084055
# Epoch [19 / 30] average reconstruction error: 33505.941161
# Epoch [20 / 30] average reconstruction error: 33509.928595
# Epoch [21 / 30] average reconstruction error: 33501.743900
# Epoch [22 / 30] average reconstruction error: 33501.285160
# Epoch [23 / 30] average reconstruction error: 33505.583074
# Epoch [24 / 30] average reconstruction error: 33507.959022
# Epoch [25 / 30] average reconstruction error: 33498.717715
# Epoch [26 / 30] average reconstruction error: 33498.379318
# Epoch [27 / 30] average reconstruction error: 33495.443916
# Epoch [28 / 30] average reconstruction error: 33493.537554
# Epoch [29 / 30] average reconstruction error: 33500.184791
# Epoch [30 / 30] average reconstruction error: 33498.699838
# Generation 2
# Number of parameters: 647081
# Training ...
# Epoch [1 / 30] average reconstruction error: 35501.051321
# Epoch [2 / 30] average reconstruction error: 35479.873695
# Epoch [3 / 30] average reconstruction error: 35478.047777
# Epoch [4 / 30] average reconstruction error: 35474.556371
# Epoch [5 / 30] average reconstruction error: 35476.106894
# Epoch [6 / 30] average reconstruction error: 35474.321252
# Epoch [7 / 30] average reconstruction error: 35470.063726
# Epoch [8 / 30] average reconstruction error: 35470.543646
# Epoch [9 / 30] average reconstruction error: 35467.220869
# Epoch [10 / 30] average reconstruction error: 35466.607725
# Epoch [11 / 30] average reconstruction error: 35471.988605
# Epoch [12 / 30] average reconstruction error: 35467.125777
# Epoch [13 / 30] average reconstruction error: 35456.716198
# Epoch [14 / 30] average reconstruction error: 35462.197457
# Epoch [15 / 30] average reconstruction error: 35459.534259
# Epoch [16 / 30] average reconstruction error: 35455.027564
# Epoch [17 / 30] average reconstruction error: 35458.288900
# Epoch [18 / 30] average reconstruction error: 35459.435526
# Epoch [19 / 30] average reconstruction error: 35456.515891
# Epoch [20 / 30] average reconstruction error: 35457.170865
# Epoch [21 / 30] average reconstruction error: 35456.694739
# Epoch [22 / 30] average reconstruction error: 35455.295944
# Epoch [23 / 30] average reconstruction error: 35451.345574
# Epoch [24 / 30] average reconstruction error: 35453.609254
# Epoch [25 / 30] average reconstruction error: 35457.145142
# Epoch [26 / 30] average reconstruction error: 35453.145878
# Epoch [27 / 30] average reconstruction error: 35453.542678
# Epoch [28 / 30] average reconstruction error: 35451.187001
# Epoch [29 / 30] average reconstruction error: 35451.253287
# Epoch [30 / 30] average reconstruction error: 35455.115322
# Generation 3
# Number of parameters: 647081
# Training ...
# Epoch [1 / 30] average reconstruction error: 37054.792379
# Epoch [2 / 30] average reconstruction error: 37024.234225
# Epoch [3 / 30] average reconstruction error: 37017.341963
# Epoch [4 / 30] average reconstruction error: 37016.343002
# Epoch [5 / 30] average reconstruction error: 37019.605593
# Epoch [6 / 30] average reconstruction error: 37015.349934
# Epoch [7 / 30] average reconstruction error: 37012.728815
# Epoch [8 / 30] average reconstruction error: 37010.273878
# Epoch [9 / 30] average reconstruction error: 37004.506674
# Epoch [10 / 30] average reconstruction error: 37006.387683
# Epoch [11 / 30] average reconstruction error: 37011.152630
# Epoch [12 / 30] average reconstruction error: 37004.808565
# Epoch [13 / 30] average reconstruction error: 37005.049730
# Epoch [14 / 30] average reconstruction error: 37008.390575
# Epoch [15 / 30] average reconstruction error: 37003.569540
# Epoch [16 / 30] average reconstruction error: 37003.437118
# Epoch [17 / 30] average reconstruction error: 37004.139773
# Epoch [18 / 30] average reconstruction error: 37000.959683
# Epoch [19 / 30] average reconstruction error: 37001.771779
# Epoch [20 / 30] average reconstruction error: 37000.720844
# Epoch [21 / 30] average reconstruction error: 37004.292154
# Epoch [22 / 30] average reconstruction error: 37003.367566
# Epoch [23 / 30] average reconstruction error: 37000.254197
# Epoch [24 / 30] average reconstruction error: 37002.542466
# Epoch [25 / 30] average reconstruction error: 36999.631690
# Epoch [26 / 30] average reconstruction error: 36995.928507
# Epoch [27 / 30] average reconstruction error: 36999.841751
# Epoch [28 / 30] average reconstruction error: 36999.362878
# Epoch [29 / 30] average reconstruction error: 36998.963290
# Epoch [30 / 30] average reconstruction error: 36992.781462
# Generation 4
# Number of parameters: 647081
# Training ...
# Epoch [1 / 30] average reconstruction error: 38364.466298
# Epoch [2 / 30] average reconstruction error: 38351.400278
# Epoch [3 / 30] average reconstruction error: 38353.149023
# Epoch [4 / 30] average reconstruction error: 38351.652227
# Epoch [5 / 30] average reconstruction error: 38341.139195
# Epoch [6 / 30] average reconstruction error: 38340.874094
# Epoch [7 / 30] average reconstruction error: 38345.897478
# Epoch [8 / 30] average reconstruction error: 38346.369357
# Epoch [9 / 30] average reconstruction error: 38339.887209
# Epoch [10 / 30] average reconstruction error: 38344.231196
# Epoch [11 / 30] average reconstruction error: 38341.435651
# Epoch [12 / 30] average reconstruction error: 38342.311690
# Epoch [13 / 30] average reconstruction error: 38345.836827
# Epoch [14 / 30] average reconstruction error: 38340.260967
# Epoch [15 / 30] average reconstruction error: 38341.854596
# Epoch [16 / 30] average reconstruction error: 38343.981333
# Epoch [17 / 30] average reconstruction error: 38343.555469
# Epoch [18 / 30] average reconstruction error: 38340.005473
# Epoch [19 / 30] average reconstruction error: 38338.688556
# Epoch [20 / 30] average reconstruction error: 38343.861877
# Epoch [21 / 30] average reconstruction error: 38340.169398
# Epoch [22 / 30] average reconstruction error: 38344.266942
# Epoch [23 / 30] average reconstruction error: 38341.306728
# Epoch [24 / 30] average reconstruction error: 38339.114004
# Epoch [25 / 30] average reconstruction error: 38336.937874
# Epoch [26 / 30] average reconstruction error: 38335.295637
# Epoch [27 / 30] average reconstruction error: 38337.830502
# Epoch [28 / 30] average reconstruction error: 38336.288992
# Epoch [29 / 30] average reconstruction error: 38342.437949
# Epoch [30 / 30] average reconstruction error: 38339.001600
# Generation 5
# Number of parameters: 647081
# Training ...
# Epoch [1 / 30] average reconstruction error: 39251.263493
# Epoch [2 / 30] average reconstruction error: 39236.977913
# Epoch [3 / 30] average reconstruction error: 39237.463306
# Epoch [4 / 30] average reconstruction error: 39232.065849
# Epoch [5 / 30] average reconstruction error: 39232.266880
# Epoch [6 / 30] average reconstruction error: 39230.374709
# Epoch [7 / 30] average reconstruction error: 39229.655190
# Epoch [8 / 30] average reconstruction error: 39229.630257
# Epoch [9 / 30] average reconstruction error: 39229.958972
# Epoch [10 / 30] average reconstruction error: 39231.653565
# Epoch [11 / 30] average reconstruction error: 39227.870599
# Epoch [12 / 30] average reconstruction error: 39225.912837
# Epoch [13 / 30] average reconstruction error: 39225.117499
# Epoch [14 / 30] average reconstruction error: 39229.923886
# Epoch [15 / 30] average reconstruction error: 39227.593285
# Epoch [16 / 30] average reconstruction error: 39231.982684
# Epoch [17 / 30] average reconstruction error: 39227.968280
# Epoch [18 / 30] average reconstruction error: 39226.256990
# Epoch [19 / 30] average reconstruction error: 39225.945055
# Epoch [20 / 30] average reconstruction error: 39232.139137
# Epoch [21 / 30] average reconstruction error: 39225.863971
# Epoch [22 / 30] average reconstruction error: 39226.570001
# Epoch [23 / 30] average reconstruction error: 39227.209658
# Epoch [24 / 30] average reconstruction error: 39229.762292
# Epoch [25 / 30] average reconstruction error: 39224.903856
# Epoch [26 / 30] average reconstruction error: 39226.711041
# Epoch [27 / 30] average reconstruction error: 39229.772947
# Epoch [28 / 30] average reconstruction error: 39226.451500
# Epoch [29 / 30] average reconstruction error: 39229.299323
# Epoch [30 / 30] average reconstruction error: 39224.939545
# Generation 6
# Number of parameters: 647081
# Training ...
# Epoch [1 / 30] average reconstruction error: 40078.965854
# Epoch [2 / 30] average reconstruction error: 40064.734396
# Epoch [3 / 30] average reconstruction error: 40064.798903
# Epoch [4 / 30] average reconstruction error: 40061.538838
# Epoch [5 / 30] average reconstruction error: 40060.492104
# Epoch [6 / 30] average reconstruction error: 40065.449439
# Epoch [7 / 30] average reconstruction error: 40060.943006
# Epoch [8 / 30] average reconstruction error: 40060.733278
# Epoch [9 / 30] average reconstruction error: 40060.159325
# Epoch [10 / 30] average reconstruction error: 40059.228869
# Epoch [11 / 30] average reconstruction error: 40056.060514
# Epoch [12 / 30] average reconstruction error: 40057.029783
# Epoch [13 / 30] average reconstruction error: 40058.507800
# Epoch [14 / 30] average reconstruction error: 40063.446917
# Epoch [15 / 30] average reconstruction error: 40053.794922
# Epoch [16 / 30] average reconstruction error: 40062.401891
# Epoch [17 / 30] average reconstruction error: 40059.175432
# Epoch [18 / 30] average reconstruction error: 40056.525540
# Epoch [19 / 30] average reconstruction error: 40061.341651
# Epoch [20 / 30] average reconstruction error: 40055.535264
# Epoch [21 / 30] average reconstruction error: 40056.695745
# Epoch [22 / 30] average reconstruction error: 40059.665791
# Epoch [23 / 30] average reconstruction error: 40059.311515
# Epoch [24 / 30] average reconstruction error: 40058.081865
# Epoch [25 / 30] average reconstruction error: 40059.939914
# Epoch [26 / 30] average reconstruction error: 40059.972868
# Epoch [27 / 30] average reconstruction error: 40055.712774
# Epoch [28 / 30] average reconstruction error: 40058.200058
# Epoch [29 / 30] average reconstruction error: 40058.351791
# Epoch [30 / 30] average reconstruction error: 40056.516681
# Generation 7
# Number of parameters: 647081
# Training ...
# Epoch [1 / 30] average reconstruction error: 41034.389931
# Epoch [2 / 30] average reconstruction error: 41032.036108
# Epoch [3 / 30] average reconstruction error: 41030.290430
# Epoch [4 / 30] average reconstruction error: 41028.680776
# Epoch [5 / 30] average reconstruction error: 41030.567624
# Epoch [6 / 30] average reconstruction error: 41027.211449
# Epoch [7 / 30] average reconstruction error: 41029.463518
# Epoch [8 / 30] average reconstruction error: 41025.200736
# Epoch [9 / 30] average reconstruction error: 41027.421085
# Epoch [10 / 30] average reconstruction error: 41027.352115
# Epoch [11 / 30] average reconstruction error: 41025.877327
# Epoch [12 / 30] average reconstruction error: 41028.539474
# Epoch [13 / 30] average reconstruction error: 41024.386661
# Epoch [14 / 30] average reconstruction error: 41029.312828
# Epoch [15 / 30] average reconstruction error: 41024.428773
# Epoch [16 / 30] average reconstruction error: 41029.150058
# Epoch [17 / 30] average reconstruction error: 41025.625266
# Epoch [18 / 30] average reconstruction error: 41023.278487
# Epoch [19 / 30] average reconstruction error: 41024.639241
# Epoch [20 / 30] average reconstruction error: 41027.897876
# Epoch [21 / 30] average reconstruction error: 41028.117059
# Epoch [22 / 30] average reconstruction error: 41023.922594
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 12
#      10 train_recon = TensorDataset(img_recon, torch.zeros(60000, 1))
#      11 train_dataloader = DataLoader(train_recon, batch_size=batch_size, shuffle=True)
# ---> 12 train_vae_gen(vae_init, False, None)
#
# Cell In[6], line 36, in train_vae_gen(vae, sample_vae, sample_from)
#      34 # backpropagation
#      35 optimizer.zero_grad()
# ---> 36 loss.backward()
#      38 # one step of the optmizer (using the gradients from backpropagation)
#      39 optimizer.step()
#
# File /usr/local/lib/python3.9/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File /usr/local/lib/python3.9/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(figsize=(5, 5))
show_image(make_grid(samples[0],10,5))
# plt.show()
plt.xticks([])
plt.yticks([])

plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(5, 5))
show_image(make_grid(samples[7],10,5))
# plt.show()
plt.xticks([])
plt.yticks([])

plt.tight_layout()
