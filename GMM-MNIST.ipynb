# %%
from sklearn.mixture import GaussianMixture
from sklearn.datasets import fetch_openml
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

# %%
mnist = fetch_openml("mnist_784")
X, y = mnist.data, mnist.target

# Shuffle the dataset
X, y = shuffle(X, y)
X_train, X_test, y_train, y_test = X[:2560], X[60000:], y[:2560], y[60000]
# Out:
# /gpfs/home/ngok02/.conda/envs/ModelCollapse/lib/python3.10/site-packages/sklearn/datasets/_openml.py:107: UserWarning: A network error occurred while downloading https://api.openml.org/api/v1/json/data/list/data_name/mnist_784/limit/2/status/active/. Retrying...
#   warn(
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/.conda/envs/ModelCollapse/lib/python3.10/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/http/client.py:1283, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1282 """Send a complete request to the server."""
# -> 1283 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/http/client.py:1329, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1328     body = _encode(body, 'body')
# -> 1329 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/http/client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/http/client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/http/client.py:976, in HTTPConnection.send(self, data)
#     975 if self.auto_open:
# --> 976     self.connect()
#     977 else:
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/http/client.py:1448, in HTTPSConnection.connect(self)
#    1446 "Connect to a host on a given (SSL) port."
# -> 1448 super().connect()
#    1450 if self._tunnel_host:
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/http/client.py:942, in HTTPConnection.connect(self)
#     941 sys.audit("http.client.connect", self, self.host, self.port)
# --> 942 self.sock = self._create_connection(
#     943     (self.host,self.port), self.timeout, self.source_address)
#     944 # Might fail in OSs that don't implement TCP_NODELAY
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/socket.py:857, in create_connection(address, timeout, source_address)
#     856 try:
# --> 857     raise err
#     858 finally:
#     859     # Break explicitly a reference cycle
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/socket.py:845, in create_connection(address, timeout, source_address)
#     844     sock.bind(source_address)
# --> 845 sock.connect(sa)
#     846 # Break explicitly a reference cycle
#
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 mnist = fetch_openml("mnist_784")
#       2 X, y = mnist.data, mnist.target
#       4 # Shuffle the dataset
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/site-packages/sklearn/datasets/_openml.py:1008, in fetch_openml(name, version, data_id, data_home, target_column, cache, return_X_y, as_frame, n_retries, delay, parser, read_csv_kwargs)
#    1002     if data_id is not None:
#    1003         raise ValueError(
#    1004             "Dataset data_id={} and name={} passed, but you can only "
#    1005             "specify a numeric data_id or a name, not "
#    1006             "both.".format(data_id, name)
#    1007         )
# -> 1008     data_info = _get_data_info_by_name(
#    1009         name, version, data_home, n_retries=n_retries, delay=delay
#    1010     )
#    1011     data_id = data_info["did"]
#    1012 elif data_id is not None:
#    1013     # from the previous if statement, it is given that name is None
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/site-packages/sklearn/datasets/_openml.py:299, in _get_data_info_by_name(name, version, data_home, n_retries, delay)
#     297 url = _SEARCH_NAME.format(name) + "/status/active/"
#     298 error_msg = "No active dataset {} found.".format(name)
# --> 299 json_data = _get_json_content_from_openml_api(
#     300     url,
#     301     error_msg,
#     302     data_home=data_home,
#     303     n_retries=n_retries,
#     304     delay=delay,
#     305 )
#     306 res = json_data["data"]["dataset"]
#     307 if len(res) > 1:
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/site-packages/sklearn/datasets/_openml.py:243, in _get_json_content_from_openml_api(url, error_message, data_home, n_retries, delay)
#     240         return json.loads(response.read().decode("utf-8"))
#     242 try:
# --> 243     return _load_json()
#     244 except HTTPError as error:
#     245     # 412 is an OpenML specific error code, indicating a generic error
#     246     # (e.g., data not found)
#     247     if error.code != 412:
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/site-packages/sklearn/datasets/_openml.py:64, in _retry_with_clean_cache.<locals>.decorator.<locals>.wrapper(*args, **kw)
#      62     return f(*args, **kw)
#      63 try:
# ---> 64     return f(*args, **kw)
#      65 except URLError:
#      66     raise
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/site-packages/sklearn/datasets/_openml.py:238, in _get_json_content_from_openml_api.<locals>._load_json()
#     235 @_retry_with_clean_cache(url, data_home=data_home)
#     236 def _load_json():
#     237     with closing(
# --> 238         _open_openml_url(url, data_home, n_retries=n_retries, delay=delay)
#     239     ) as response:
#     240         return json.loads(response.read().decode("utf-8"))
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/site-packages/sklearn/datasets/_openml.py:170, in _open_openml_url(openml_path, data_home, n_retries, delay)
#     163 try:
#     164     # Create a tmpdir as a subfolder of dir_name where the final file will
#     165     # be moved to if the download is successful. This guarantees that the
#     166     # renaming operation to the final location is atomic to ensure the
#     167     # concurrence safety of the dataset caching mechanism.
#     168     with TemporaryDirectory(dir=dir_name) as tmpdir:
#     169         with closing(
# --> 170             _retry_on_network_error(n_retries, delay, req.full_url)(urlopen)(
#     171                 req
#     172             )
#     173         ) as fsrc:
#     174             opener: Callable
#     175             if is_gzip_encoded(fsrc):
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/site-packages/sklearn/datasets/_openml.py:100, in _retry_on_network_error.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      98 while True:
#      99     try:
# --> 100         return f(*args, **kwargs)
#     101     except (URLError, TimeoutError) as e:
#     102         # 412 is a specific OpenML error code.
#     103         if isinstance(e, HTTPError) and e.code == 412:
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/urllib/request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File ~/.conda/envs/ModelCollapse/lib/python3.10/urllib/request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error [Errno 110] Connection timed out>

# %%
image= X_train.to_numpy()
plt.subplot(431)
plt.imshow((image[0].reshape(28,28)), cmap=plt.cm.gray_r, 
interpolation="nearest")

# %%
gmm = GaussianMixture(n_components=10)
gmm.fit(X_train)

# %%
image= X_train.to_numpy()
plt.subplot(431)
plt.imshow((image[0].reshape(28,28)), cmap=plt.cm.gray_r, 
interpolation="nearest")
